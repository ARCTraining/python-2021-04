# %% [markdown]
# # Starting with Data with Pandas

# %%
# Author: Martin Callaghan
# Date: 2021-10-18
# Lesson link: https://arctraining.github.io/python-2021-04/02-starting-with-data/index.html

# %%
# Connect my Google Drive to Google Colab
from google.colab import drive
drive.mount ('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Change the working directory
# %cd /content/gdrive/MyDrive/swd1a-python-2021-10
# Out:
# /content/gdrive/.shortcut-targets-by-id/1c-UzOKbLCZjy_P7oCGtvGKn-RoOvpDyC/swd1a-python-2021-10

# %%
# Check the working directory
# !pwd
# Out:
# /content/gdrive/.shortcut-targets-by-id/1c-UzOKbLCZjy_P7oCGtvGKn-RoOvpDyC/swd1a-python-2021-10

# %%
# We use the Portal Project teaching dataset
# https://figshare.com/articles/dataset/Portal_Project_Teaching_Database/1314459

# %%
# But first we need to download it
# !wget -O data.zip https://arctraining.github.io/python-2021-04/data/portal-teachingdb-master.zip
# Out:
# --2021-10-18 13:53:56--  https://arctraining.github.io/python-2021-04/data/portal-teachingdb-master.zip
# Resolving arctraining.github.io (arctraining.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to arctraining.github.io (arctraining.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 689547 (673K) [application/zip]
# Saving to: ‘data.zip’
#
# data.zip            100%[===================>] 673.39K  --.-KB/s    in 0.05s
#
# 2021-10-18 13:53:56 (14.0 MB/s) - ‘data.zip’ saved [689547/689547]

# %%
# Check the contents of the current working directory
# !ls -l
# Out:
# total 714
# -rw------- 1 root root  35824 Oct 18 13:50 010_starting_with_python.ipynb
# -rw------- 1 root root   4790 Oct 18 14:09 020_starting_with_data.ipynb
# -rw------- 1 root root 689547 May 17 13:50 data.zip

# %%
# Unzip the data.zip file
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: portal-teachingdb-master/
#   inflating: portal-teachingdb-master/surveys2001.csv
#   inflating: portal-teachingdb-master/surveys2002.csv
#   inflating: portal-teachingdb-master/speciesSubset.csv
#   inflating: portal-teachingdb-master/bouldercreek_09_2013.txt
#   inflating: portal-teachingdb-master/species.csv
#   inflating: portal-teachingdb-master/surveys.csv
#   inflating: portal-teachingdb-master/portal_mammals.sqlite
#   inflating: portal-teachingdb-master/README.txt
#   inflating: portal-teachingdb-master/plots.csv

# %%
# Check the contents of the current working directory
# !ls -l
# Out:
# total 83
# -rw------- 1 root root 35824 Oct 18 13:50 010_starting_with_python.ipynb
# -rw------- 1 root root 44917 Oct 25 10:37 020_starting_with_data.ipynb
# drwx------ 2 root root  4096 Oct 18 14:12 data

# %%
# Rename the folder portal-teachingdb-master to data
# !mv portal-teachingdb-master/ data/

# %%
# Check the contents of the current working directory
# !ls -l
# Out:
# total 721
# -rw------- 1 root root  35824 Oct 18 13:50 010_starting_with_python.ipynb
# -rw------- 1 root root   8066 Oct 18 14:12 020_starting_with_data.ipynb
# drwx------ 2 root root   4096 Oct 18 14:12 data
# -rw------- 1 root root 689547 May 17 13:50 data.zip

# %% [markdown]
# ## Exploring the data

# %%
# import the pandas library
import pandas as pd

# %%
# First have a look at surveys.csv
pd.read_csv('data/surveys.csv')
# Out:
#        record_id  month  day  year  ...  species_id  sex hindfoot_length  weight
# 0              1      7   16  1977  ...          NL    M            32.0     NaN
# 1              2      7   16  1977  ...          NL    M            33.0     NaN
# 2              3      7   16  1977  ...          DM    F            37.0     NaN
# 3              4      7   16  1977  ...          DM    M            36.0     NaN
# 4              5      7   16  1977  ...          DM    M            35.0     NaN
# ...          ...    ...  ...   ...  ...         ...  ...             ...     ...
# 35544      35545     12   31  2002  ...          AH  NaN             NaN     NaN
# 35545      35546     12   31  2002  ...          AH  NaN             NaN     NaN
# 35546      35547     12   31  2002  ...          RM    F            15.0    14.0
# 35547      35548     12   31  2002  ...          DO    M            36.0    51.0
# 35548      35549     12   31  2002  ...         NaN  NaN             NaN     NaN
#
# ...

# %%
# Read in the df and assign it to a variable
surveys_df = pd.read_csv('data/surveys.csv')

# %%
# Quickly view the contents
surveys_df
# Out:
#        record_id  month  day  year  ...  species_id  sex hindfoot_length  weight
# 0              1      7   16  1977  ...          NL    M            32.0     NaN
# 1              2      7   16  1977  ...          NL    M            33.0     NaN
# 2              3      7   16  1977  ...          DM    F            37.0     NaN
# 3              4      7   16  1977  ...          DM    M            36.0     NaN
# 4              5      7   16  1977  ...          DM    M            35.0     NaN
# ...          ...    ...  ...   ...  ...         ...  ...             ...     ...
# 35544      35545     12   31  2002  ...          AH  NaN             NaN     NaN
# 35545      35546     12   31  2002  ...          AH  NaN             NaN     NaN
# 35546      35547     12   31  2002  ...          RM    F            15.0    14.0
# 35547      35548     12   31  2002  ...          DO    M            36.0    51.0
# 35548      35549     12   31  2002  ...         NaN  NaN             NaN     NaN
#
# ...

# %%
# Look at the first few rows
surveys_df.head(4)
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  weight
# 0          1      7   16  1977        2         NL   M             32.0     NaN
# 1          2      7   16  1977        3         NL   M             33.0     NaN
# 2          3      7   16  1977        2         DM   F             37.0     NaN
# 3          4      7   16  1977        7         DM   M             36.0     NaN

# %%
# Look at the bottom few rows
surveys_df.tail(5)
# Out:
#        record_id  month  day  year  ...  species_id  sex hindfoot_length  weight
# 35544      35545     12   31  2002  ...          AH  NaN             NaN     NaN
# 35545      35546     12   31  2002  ...          AH  NaN             NaN     NaN
# 35546      35547     12   31  2002  ...          RM    F            15.0    14.0
# 35547      35548     12   31  2002  ...          DO    M            36.0    51.0
# 35548      35549     12   31  2002  ...         NaN  NaN             NaN     NaN
#
# [5 rows x 9 columns]

# %%
# What type of thing is surveys_df
type (surveys_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# What are the data types of the columns
surveys_df.dtypes
# Out:
# record_id            int64
# month                int64
# day                  int64
# year                 int64
# plot_id              int64
# species_id          object
# sex                 object
# hindfoot_length    float64
# weight             float64
# dtype: object

# %%
# What are the columns
surveys_df.columns
# Out:
# Index(['record_id', 'month', 'day', 'year', 'plot_id', 'species_id', 'sex',
#        'hindfoot_length', 'weight'],
#       dtype='object')

# %%
# What is the shape (rows x columns)?
surveys_df.shape
# Out:
# (35549, 9)

# %%
# What are the unique values of the categorical data in species
pd.unique(surveys_df['species_id'])
# Out:
# array(['NL', 'DM', 'PF', 'PE', 'DS', 'PP', 'SH', 'OT', 'DO', 'OX', 'SS',
#        'OL', 'RM', nan, 'SA', 'PM', 'AH', 'DX', 'AB', 'CB', 'CM', 'CQ',
#        'RF', 'PC', 'PG', 'PH', 'PU', 'CV', 'UR', 'UP', 'ZL', 'UL', 'CS',
#        'SC', 'BA', 'SF', 'RO', 'AS', 'SO', 'PI', 'ST', 'CU', 'SU', 'RX',
#        'PB', 'PL', 'PX', 'CT', 'US'], dtype=object)

# %%
# Challenge 1: Stats
# What are the unique values of 'plot_id'
site_names = pd.unique(surveys_df['plot_id'])

# %%
site_names
# Out:
# array([ 2,  3,  7,  1,  6,  5,  8,  4, 11, 14, 15, 13,  9, 10, 17, 16, 20,
#        23, 18, 21, 22, 19, 12, 24])

# %%
# How many unique plot_id are there?
pd.unique(surveys_df['plot_id']).shape
# Out:
# (24,)

# %%
len(site_names)
# Out:
# 24

# %%
# How many unique species_id are there?
len(pd.unique(surveys_df['species_id']))
# Out:
# 49

# %%
# What is the difference between running the commands 
# len(site_names) and 
# surveys_df['plot_id'].nunique()?

# %%
# Descriptive statistics of the dataframe
surveys_df['weight'].describe()
# Out:
# count    32283.000000
# mean        42.672428
# std         36.631259
# min          4.000000
# 25%         20.000000
# 50%         37.000000
# 75%         48.000000
# max        280.000000
# Name: weight, dtype: float64

# %%
# If I wanted just a single metric
surveys_df['weight'].max()
# Out:
# 280.0

# %%
surveys_df['weight'].mean()
# Out:
# 42.672428212991356

# %%
# If we wanted to summarise by one or more variables, for example sex, we can use
# the groupby method in pandas.

# %%
# group the data by sex
grouped_data = surveys_df.groupby('sex')

# %%
# Summary stats
grouped_data.describe()
# Out:
#     record_id                                   ... weight
#         count          mean           std  min  ...    25%   50%   75%    max
# sex                                             ...
# F     15690.0  18036.412046  10423.089000  3.0  ...   20.0  34.0  46.0  274.0
# M     17348.0  17754.835601  10132.203323  1.0  ...   20.0  39.0  49.0  280.0
#
# [2 rows x 56 columns]

# %%
# But just the mean values
grouped_data.mean()
# Out:
#         record_id     month        day  ...    plot_id  hindfoot_length     weight
# sex                                     ...
# F    18036.412046  6.587253  15.880943  ...  11.440854        28.836780  42.170555
# M    17754.835601  6.396184  16.078799  ...  11.098282        29.709578  42.995379
#
# [2 rows x 7 columns]

# %% [markdown]
# ### Challenge 2: summary data
#
# 1. How many recorded individuals are female `F` and how many male `M`?
# 2. What happens when you group by two columns using the following syntax and then calculate mean values?
# * grouped_data2 = surveys_df.groupby(['plot_id', 'sex'])
# * grouped_data2.mean()
# 3. Summarise weight values for each site in your data. HINT: you can use the following syntax to only create summary statistics for one column in your data. by_site['weight'].describe()

# %%
grouped_data.count()
# Out:
#      record_id  month    day  ...  species_id  hindfoot_length  weight
# sex                           ...
# F        15690  15690  15690  ...       15690            14894   15303
# M        17348  17348  17348  ...       17348            16476   16879
#
# [2 rows x 8 columns]

# %%
grouped_data2 = surveys_df.groupby(['plot_id', 'sex'])
grouped_data2.mean()
# Out:
#                 record_id     month  ...  hindfoot_length     weight
# plot_id sex                          ...
# 1       F    18390.384434  6.597877  ...        31.733911  46.311138
#         M    17197.740639  6.121461  ...        34.302770  55.950560
# 2       F    17714.753608  6.426804  ...        30.161220  52.561845
#         M    18085.458042  6.340035  ...        30.353760  51.391382
# 3       F    19888.783875  6.610302  ...        23.774044  31.215349
#         M    20226.767857  6.277381  ...        23.833744  34.163241
# 4       F    17489.205275  6.447248  ...        33.249102  46.818824
#         M    18493.841748  6.436893  ...        34.097959  48.888119
# 5       F    12280.793169  6.142315  ...        28.921844  40.974806
#         M    12798.426621  6.194539  ...        29.694794  40.708551
# 6       F    19406.503392  6.640434  ...        26.981322  36.352288
#         M    17849.574607  6.043194  ...        27.425591  36.867388
# ...

# %%
by_site = surveys_df.groupby(['plot_id'])
by_site['weight'].describe()
# Out:
#           count       mean        std  min   25%   50%   75%    max
# plot_id
# 1        1903.0  51.822911  38.176670  4.0  30.0  44.0  53.0  231.0
# 2        2074.0  52.251688  46.503602  5.0  24.0  41.0  50.0  278.0
# 3        1710.0  32.654386  35.641630  4.0  14.0  23.0  36.0  250.0
# 4        1866.0  47.928189  32.886598  4.0  30.0  43.0  50.0  200.0
# 5        1092.0  40.947802  34.086616  5.0  21.0  37.0  48.0  248.0
# 6        1463.0  36.738893  30.648310  5.0  18.0  30.0  45.0  243.0
# 7         638.0  20.663009  21.315325  4.0  11.0  17.0  23.0  235.0
# 8        1781.0  47.758001  33.192194  5.0  26.0  44.0  51.0  178.0
# 9        1811.0  51.432358  33.724726  6.0  36.0  45.0  50.0  275.0
# 10        279.0  18.541219  20.290806  4.0  10.0  12.0  21.0  237.0
# 11       1793.0  43.451757  28.975514  5.0  26.0  42.0  48.0  212.0
# 12       2219.0  49.496169  41.630035  6.0  26.0  42.0  50.0  280.0
# 13       1371.0  40.445660  34.042767  5.0  20.5  33.0  45.0  241.0
# ...

# %%
    What happens when you execute:
        

    What happens when you call:
        surveys_df.iloc[0:4, 1:4]
        surveys_df.loc[0:4, 1:4]

    How are the two commands different?
# Out:
#   File "<ipython-input-36-417f6eaa4deb>", line 3
#     What happens when you execute:
#     ^
# IndentationError: unexpected indent

# %%
surveys_df[:-1]
# Out:
#        record_id  month  day  year  ...  species_id  sex hindfoot_length  weight
# 0              1      7   16  1977  ...          NL    M            32.0     NaN
# 1              2      7   16  1977  ...          NL    M            33.0     NaN
# 2              3      7   16  1977  ...          DM    F            37.0     NaN
# 3              4      7   16  1977  ...          DM    M            36.0     NaN
# 4              5      7   16  1977  ...          DM    M            35.0     NaN
# ...          ...    ...  ...   ...  ...         ...  ...             ...     ...
# 35543      35544     12   31  2002  ...          US  NaN             NaN     NaN
# 35544      35545     12   31  2002  ...          AH  NaN             NaN     NaN
# 35545      35546     12   31  2002  ...          AH  NaN             NaN     NaN
# 35546      35547     12   31  2002  ...          RM    F            15.0    14.0
# 35547      35548     12   31  2002  ...          DO    M            36.0    51.0
#
# ...

# %%
surveys_df.loc[0:4, 1:4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-aed7dd61eef6> in <module>()
# ----> 1 surveys_df.loc[0:4, 1:4]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1053             return self._multi_take(tup)
#    1054
# -> 1055         return self._getitem_tuple_same_dim(tup)
#    1056
#    1057     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
# ...

# %%
survey_df_test = surveys_df.copy()

# %%
survey_df_test.columns[0:3] = [0, 1, 2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-5d2b8ee37bb6> in <module>()
# ----> 1 survey_df_test.columns[0:3] = [0, 1, 2]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    4082
#    4083     def __setitem__(self, key, value):
# -> 4084         raise TypeError("Index does not support mutable operations")
#    4085
#    4086     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations
